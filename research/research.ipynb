# %%
example = {"key1": "value1", "key2": "value2"}
example["key1"]
# Out:
# 'value1'

# %%
example.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 example.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox
example = ConfigBox({"key1": "value1", "key2": "value2"})
example.key1
# Out:
# 'value1'

# %%
def product(a: int, b: int) -> int:
    return a * b
result = product(2, "3")
print(result)
# Out:
# 33

# %%
from ensure import ensure_annotations
@ensure_annotations
def product(a: int, b: int) -> int:
    return a * b
result = product(2, "3")
print(result)
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[6], line 5
#       2 @ensure_annotations
#       3 def product(a: int, b: int) -> int:
#       4     return a * b
# ----> 5 result = product(2, "3")
#       6 print(result)
#
# File d:\mlops\datascienceproject\.venv\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument b of type <class 'str'> to <function product at 0x000001E96EE431A0> does not match annotation type <class 'int'>
