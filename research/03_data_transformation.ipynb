# %%
import os
# %pwd
# Out:
# 'd:\\mlops\\datascienceproject\\research'

# %%
os.chdir("d:/mlops/datascienceproject/")
# %pwd
# Out:
# 'd:\\mlops\\datascienceproject'

# %%
import pandas as pd
data = pd.read_csv("artifacts/data_ingestion/winequality-red.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
from dataclasses import dataclass
from pathlib import Path
@dataclass
class DatatrTransformationConfig:
    root_dir: Path 
    data_path: Path

# %%
from src.DataScienceProject.constants import *
from src.DataScienceProject.utils.common import read_yaml, create_directories

class ConfigurationManager:
    def __init__(
        self,
        config_file_path=CONFIG_FILE_PATH,
        params_file_path=PARAMS_FILE_PATH,
        schema_file_path=SCHEMA_FILE_PATH,
    ):
        self.config = read_yaml(config_file_path)
        self.params = read_yaml(params_file_path)
        self.schema = read_yaml(schema_file_path)

        # create artifact root
        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DatatrTransformationConfig:
        config = self.config.data_trasformation     # Accessing data_transformation section from config.yaml

        create_directories([Path(config.root_dir)])

        data_transformation_config = DatatrTransformationConfig(
            root_dir=Path(config.root_dir),
            data_path=Path(config.data_path)
        )

        return data_transformation_config

# %%
import os
from src.DataScienceProject import logger
from sklearn.model_selection import train_test_split

class Datatransformation:
    def __init__(self, config: DatatrTransformationConfig):
        self.config = config

    ## Note: You can add different data transformation techniques such as Scaler , PCA and all

    def train_test_splitting(self):
        data = pd.read_csv(self.config.data_path)

        #Split the data into tranining and test sets. (0.75,0.25) split
        train , test = train_test_split(data)
        train.to_csv(os.path.join(self.config.root_dir, "train.csv"),index = False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"),index = False)

        logger.info("Splited dat into training and test sets")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config=ConfigurationManager()
    data_validation_config=config.get_data_transformation_config()
    data_validation=Datatransformation(config=data_validation_config)
    data_validation.train_test_splitting()
except Exception as e:
    raise e
# Out:
# [2025-12-13 12:55:13,271: INFO: common: YAML file: config\config.yaml loaded successfully]
# [2025-12-13 12:55:13,275: INFO: common: YAML file: params.yaml loaded successfully]
# [2025-12-13 12:55:13,280: INFO: common: YAML file: schema.yaml loaded successfully]
# [2025-12-13 12:55:13,282: INFO: common: created directory at: artifacts]
# [2025-12-13 12:55:13,284: INFO: common: created directory at: artifacts\data_trasformation]
# [2025-12-13 12:55:13,367: INFO: 2492608482: Splited dat into training and test sets]
# [2025-12-13 12:55:13,368: INFO: 2492608482: (1199, 12)]
# [2025-12-13 12:55:13,369: INFO: 2492608482: (400, 12)]
# (1199, 12)
# (400, 12)
